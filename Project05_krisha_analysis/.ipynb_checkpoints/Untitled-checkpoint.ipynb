# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv( "data.csv" )
df
# Out:
#               ID                                              Title  \
# 0      671727785    2-комнатная квартира, 47 м², 5/5 этаж, Сатпаева
# 1      671333442  2-комнатная квартира, 34 м², 3/5 этаж, 3мкр до...
# 2      671772801   1-комнатная квартира, 33 м², 4/9 этаж, Красина 3
# 3      671619151  1-комнатная квартира, 38 м², 3/9 этаж, Московс...
# 4      668003456  4-комнатная квартира, 155 м², 2/7 этаж, Калдая...
# ...          ...                                                ...
# 24127  667838418  2-комнатная квартира, 48 м², 1/5 этаж, Привокз...
# 24128  668502379  1-комнатная квартира, 16.5 м², 3/5 этаж, Васил...
# 24129  666476278  3-комнатная квартира, 85 м², 1/9 этаж, Нур Акт...
# 24130  662931830  2-комнатная квартира, 46 м², 8/9 этаж, 27-й мк...
# 24131  669986579  3-комнатная квартира, 70 м², 9/10 этаж, Металл...
#
#        Apartment     Price                 City                     District  \
# ...

# %%
df.info( )
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24132 entries, 0 to 24131
# Data columns (total 13 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   ID                   24132 non-null  int64
#  1   Title                24132 non-null  object
#  2   Apartment            24132 non-null  int64
#  3   Price                24132 non-null  int64
#  4   City                 24132 non-null  object
#  5   District             23164 non-null  object
#  6   Type Home            24132 non-null  object
#  7   Floor                24132 non-null  int64
#  8   Area                 24132 non-null  float64
#  9   Condition            17297 non-null  object
#  10  Residential Complex  7564 non-null   object
#  11  Year                 24132 non-null  int64
#  12  Link                 24132 non-null  object
# dtypes: float64(1), int64(5), object(7)
# memory usage: 2.4+ MB

# %%
df["Condition"].value_counts( )
# Out:
# хорошее                 12643
# среднее                  1847
# черновая отделка         1581
# требует ремонта           728
# свободная планировка      498
# Name: Condition, dtype: int64

# %%
df[df["Condition"].isna( )]
# Out:
#               ID                                              Title  \
# 1      671333442  2-комнатная квартира, 34 м², 3/5 этаж, 3мкр до...
# 13      54845217  2-комнатная квартира, 73 м², 12/13 этаж, Утеге...
# 14     671766686  2-комнатная квартира, 78 м², 3/12 этаж, Марков...
# 29     671539252  2-комнатная квартира, 48 м², 5/5 этаж, Турысов...
# 33     671399559  3-комнатная квартира, 84 м², 3/4 этаж, мкр Нов...
# ...          ...                                                ...
# 24108   28687960  3-комнатная квартира, 101.9 м², 22/25 этаж, Аб...
# 24113  671306912          2-комнатная квартира, 83 м², мкр. Батыс-2
# 24114  671831843  3-комнатная квартира, 121 м², 6/7 этаж, Мәңгіл...
# 24116  671382913  1-комнатная квартира, 30 м², 2/4 этаж, Мкр 3 1...
# 24117  671173480  3-комнатная квартира, 65 м², 6/6 этаж, Беркимб...
#
#        Apartment      Price  \
# 1              2    6500000
# 13             2   43800000
# 14             2   63000000
# 29             2   16990000
# ...

# %%
df["District"].value_counts( )
# Out:
# Есильский р-н                  2479
# Бостандыкский р-н              2302
# Алматы р-н                     1704
# Восточно-Казахстанская обл.    1357
# Алмалинский р-н                1284
#                                ...
# мкр "Самал"                       1
# 3Б мкр                            1
# мкр "Шыгыс 1"                     1
# жилой массив Ясное                1
# 10-й мкр                          1
# Name: District, Length: 134, dtype: int64

# %%
plt.bar( df["Condition"], df["Price"] )
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_2976/622323549.py in <module>
# ----> 1 plt.bar( df["Condition"], df["Price"] )
#
# D:\anaconda3\lib\site-packages\matplotlib\pyplot.py in bar(x, height, width, bottom, align, data, **kwargs)
#    2649         x, height, width=0.8, bottom=None, *, align='center',
#    2650         data=None, **kwargs):
# -> 2651     return gca().bar(
#    2652         x, height, width=width, bottom=bottom, align=align,
#    2653         **({"data": data} if data is not None else {}), **kwargs)
#
# D:\anaconda3\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1359     def inner(ax, *args, data=None, **kwargs):
#    1360         if data is None:
# -> 1361             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1362
# ...

# %%
df["Type Home"].value_counts( )
# Out:
# кирпичный     8768
# монолитный    7740
# панельный     5498
# иное           421
# 2021 г.п.      163
#               ...
# 1935 г.п.        1
# 2024 г.п.        1
# 1955 г.п.        1
# 1956 г.п.        1
# 2002 г.п.        1
# Name: Type Home, Length: 83, dtype: int64

# %%
import seaborn as sns

# %%
sns.pairplot( data = df, x_vars = ["Floor", "Area", "Year"], y_vars = "Price", height = 5 )
